# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from keras_tuner import HyperModel
from keras_tuner.tuners import RandomSearch
from keras_tuner.tuners import Hyperband
from tensorflow import keras

import pickle

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X.astype("float32")/255.0

class MLPHyperModel(HyperModel):
    def __init__(self, input_shape, num_classes):
        self.input_shape = input_shape
        self.num_classes = num_classes

    def build(self, hp):
        model = Sequential()
        
        model.add(Flatten(input_shape=X.shape[1:]))
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_1',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_1',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_1',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_2',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_2',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_2',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_3',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_3',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_3',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_4',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_4',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_4',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_5',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_5',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_5',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_6',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_6',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_6',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_7',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_7',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_7',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_8',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_8',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_8',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_9',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_9',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_9',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )
        
        model.add(
            Dense(
                units=hp.Int(
                    'units_10',
                    min_value=32,
                    max_value=512,
                    step=32,
                    default=128
                ),
                activation=hp.Choice(
                    'dense_activation_10',
                    values=['relu', 'tanh', 'sigmoid'],
                    default='relu'
                )
            )
        )
        model.add(
            Dropout(
                rate=hp.Float(
                    'dropout_10',
                    min_value=0.0,
                    max_value=0.5,
                    default=0.25,
                    step=0.05
                )
            )
        )

        model.add(Dense(self.num_classes, activation='sigmoid'))

        model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=0.0003),
            loss='binary_crossentropy',
            metrics=['accuracy']
        )
        return model
    
NUM_CLASSES = 1  # happy sad number of classes
INPUT_SHAPE = (48, 48, 1)  # happy sad images input shape
SEED = 1
HYPERBAND_MAX_EPOCHS = 21
MAX_TRIALS = 40
EXECUTION_PER_TRIAL = 2

hypermodel = MLPHyperModel(input_shape=INPUT_SHAPE, num_classes=NUM_CLASSES)

tuner = RandomSearch(
    hypermodel,
    objective='val_accuracy',
    seed=SEED,
    max_trials=MAX_TRIALS,
    executions_per_trial=EXECUTION_PER_TRIAL,
    directory='random_search_MLP',
    project_name='HappySad_MLP_4'
)

tuner = Hyperband(
    hypermodel,
    max_epochs=HYPERBAND_MAX_EPOCHS,
    objective='val_accuracy',
    seed=SEED,
    executions_per_trial=EXECUTION_PER_TRIAL,
    directory='hyperband_MLP',
    project_name='HappySad_MLP_4'
)

N_EPOCH_SEARCH = 21
BATCH_SIZE = 32

tuner.search(X, y, batch_size=BATCH_SIZE, epochs=N_EPOCH_SEARCH, validation_split=0.1)

tuner.results_summary()

# Retrieve the best model.
best_MLP_model = tuner.get_best_models(num_models=1)[0]
# Out:
# Trial 30 Complete [00h 01m 34s]
# val_accuracy: 0.6035196781158447
#
# Best val_accuracy So Far: 0.705486536026001
# Total elapsed time: 00h 19m 26s
# INFO:tensorflow:Oracle triggered exit
# Results summary
# Results in hyperband_MLP\HappySad_MLP_4
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# units_1: 64
# dense_activation_1: sigmoid
# dropout_1: 0.05
# units_2: 480
# dense_activation_2: relu
# dropout_2: 0.30000000000000004
# units_3: 64
# dense_activation_3: relu
# dropout_3: 0.30000000000000004
# units_4: 288
# dense_activation_4: tanh
# dropout_4: 0.2
# units_5: 256
# dense_activation_5: tanh
# dropout_5: 0.35000000000000003
# units_6: 320
# dense_activation_6: relu
# dropout_6: 0.1
# units_7: 32
# dense_activation_7: relu
# dropout_7: 0.25
# units_8: 320
# dense_activation_8: relu
# dropout_8: 0.2
# units_9: 448
# dense_activation_9: relu
# dropout_9: 0.30000000000000004
# units_10: 224
# dense_activation_10: relu
# dropout_10: 0.4
# tuner/epochs: 21
# tuner/initial_epoch: 7
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 2fc2b0339ecb4296446a919cbe4d4dd3
# Score: 0.705486536026001
# Trial summary
# Hyperparameters:
# units_1: 256
# dense_activation_1: sigmoid
# dropout_1: 0.2
# units_2: 512
# dense_activation_2: tanh
# dropout_2: 0.05
# units_3: 96
# dense_activation_3: tanh
# dropout_3: 0.0
# units_4: 192
# dense_activation_4: tanh
# dropout_4: 0.4
# units_5: 160
# dense_activation_5: relu
# dropout_5: 0.0
# units_6: 224
# dense_activation_6: sigmoid
# dropout_6: 0.4
# units_7: 416
# dense_activation_7: relu
# dropout_7: 0.1
# units_8: 160
# dense_activation_8: sigmoid
# dropout_8: 0.2
# units_9: 416
# dense_activation_9: tanh
# dropout_9: 0.45
# units_10: 192
# dense_activation_10: sigmoid
# dropout_10: 0.0
# tuner/epochs: 21
# tuner/initial_epoch: 7
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: aa85610ded5ae9a8376c3b0b14abb3ec
# Score: 0.7018633484840393
# Trial summary
# Hyperparameters:
# units_1: 448
# dense_activation_1: relu
# dropout_1: 0.30000000000000004
# units_2: 480
# dense_activation_2: relu
# dropout_2: 0.0
# units_3: 128
# dense_activation_3: relu
# dropout_3: 0.05
# units_4: 224
# dense_activation_4: sigmoid
# dropout_4: 0.05
# units_5: 128
# dense_activation_5: tanh
# dropout_5: 0.4
# units_6: 288
# dense_activation_6: tanh
# dropout_6: 0.45
# units_7: 224
# dense_activation_7: tanh
# dropout_7: 0.45
# units_8: 448
# dense_activation_8: relu
# dropout_8: 0.1
# units_9: 96
# dense_activation_9: sigmoid
# dropout_9: 0.1
# units_10: 384
# dense_activation_10: relu
# dropout_10: 0.45
# tuner/epochs: 21
# tuner/initial_epoch: 7
# tuner/bracket: 2
# tuner/round: 2
# tuner/trial_id: 2400c3af2b4a83ede67c2ecf7dabc3f5
# Score: 0.695652186870575
# Trial summary
# Hyperparameters:
# units_1: 480
# dense_activation_1: sigmoid
# dropout_1: 0.4
# units_2: 416
# dense_activation_2: sigmoid
# dropout_2: 0.05
# units_3: 64
# dense_activation_3: tanh
# dropout_3: 0.4
# units_4: 96
# dense_activation_4: tanh
# dropout_4: 0.05
# units_5: 64
# dense_activation_5: tanh
# dropout_5: 0.1
# units_6: 352
# dense_activation_6: relu
# dropout_6: 0.0
# units_7: 32
# dense_activation_7: relu
# dropout_7: 0.25
# units_8: 64
# dense_activation_8: sigmoid
# dropout_8: 0.30000000000000004
# units_9: 480
# dense_activation_9: sigmoid
# dropout_9: 0.2
# units_10: 416
# dense_activation_10: sigmoid
# dropout_10: 0.30000000000000004
# tuner/epochs: 21
# tuner/initial_epoch: 7
# tuner/bracket: 1
# tuner/round: 1
# tuner/trial_id: af361bc768f4bc7c899e5aa67e9ecb61
# Score: 0.6692546606063843
# Trial summary
# Hyperparameters:
# units_1: 256
# dense_activation_1: sigmoid
# dropout_1: 0.2
# units_2: 512
# dense_activation_2: tanh
# dropout_2: 0.05
# units_3: 96
# dense_activation_3: tanh
# dropout_3: 0.0
# units_4: 192
# dense_activation_4: tanh
# dropout_4: 0.4
# units_5: 160
# dense_activation_5: relu
# dropout_5: 0.0
# units_6: 224
# dense_activation_6: sigmoid
# dropout_6: 0.4
# units_7: 416
# dense_activation_7: relu
# dropout_7: 0.1
# units_8: 160
# dense_activation_8: sigmoid
# dropout_8: 0.2
# units_9: 416
# dense_activation_9: tanh
# dropout_9: 0.45
# units_10: 192
# dense_activation_10: sigmoid
# dropout_10: 0.0
# tuner/epochs: 7
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.6149068474769592
# Trial summary
# Hyperparameters:
# units_1: 64
# dense_activation_1: sigmoid
# dropout_1: 0.05
# units_2: 480
# dense_activation_2: relu
# dropout_2: 0.30000000000000004
# units_3: 64
# dense_activation_3: relu
# dropout_3: 0.30000000000000004
# units_4: 288
# dense_activation_4: tanh
# dropout_4: 0.2
# units_5: 256
# dense_activation_5: tanh
# dropout_5: 0.35000000000000003
# units_6: 320
# dense_activation_6: relu
# dropout_6: 0.1
# units_7: 32
# dense_activation_7: relu
# dropout_7: 0.25
# units_8: 320
# dense_activation_8: relu
# dropout_8: 0.2
# units_9: 448
# dense_activation_9: relu
# dropout_9: 0.30000000000000004
# units_10: 224
# dense_activation_10: relu
# dropout_10: 0.4
# tuner/epochs: 7
# tuner/initial_epoch: 3
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 928a12e4bd8d3c6d52ef2cbc70dcbc90
# Score: 0.608178049325943
# Trial summary
# Hyperparameters:
# units_1: 448
# dense_activation_1: relu
# dropout_1: 0.30000000000000004
# units_2: 480
# dense_activation_2: relu
# dropout_2: 0.0
# units_3: 128
# dense_activation_3: relu
# dropout_3: 0.05
# units_4: 224
# dense_activation_4: sigmoid
# dropout_4: 0.05
# units_5: 128
# dense_activation_5: tanh
# dropout_5: 0.4
# units_6: 288
# dense_activation_6: tanh
# dropout_6: 0.45
# units_7: 224
# dense_activation_7: tanh
# dropout_7: 0.45
# units_8: 448
# dense_activation_8: relu
# dropout_8: 0.1
# units_9: 96
# dense_activation_9: sigmoid
# dropout_9: 0.1
# units_10: 384
# dense_activation_10: relu
# dropout_10: 0.45
# tuner/epochs: 7
# tuner/initial_epoch: 3
# tuner/bracket: 2
# tuner/round: 1
# tuner/trial_id: 0efe97187c63261a69015a30eff0c998
# Score: 0.6035196781158447
# Trial summary
# Hyperparameters:
# units_1: 416
# dense_activation_1: tanh
# dropout_1: 0.0
# units_2: 96
# dense_activation_2: tanh
# dropout_2: 0.1
# units_3: 256
# dense_activation_3: sigmoid
# dropout_3: 0.35000000000000003
# units_4: 32
# dense_activation_4: tanh
# dropout_4: 0.35000000000000003
# units_5: 288
# dense_activation_5: tanh
# dropout_5: 0.1
# units_6: 320
# dense_activation_6: sigmoid
# dropout_6: 0.30000000000000004
# units_7: 192
# dense_activation_7: tanh
# dropout_7: 0.0
# units_8: 96
# dense_activation_8: sigmoid
# dropout_8: 0.35000000000000003
# units_9: 416
# dense_activation_9: sigmoid
# dropout_9: 0.30000000000000004
# units_10: 96
# dense_activation_10: sigmoid
# dropout_10: 0.0
# tuner/epochs: 21
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.6035196781158447
# Trial summary
# Hyperparameters:
# units_1: 128
# dense_activation_1: tanh
# dropout_1: 0.1
# units_2: 64
# dense_activation_2: relu
# dropout_2: 0.35000000000000003
# units_3: 352
# dense_activation_3: relu
# dropout_3: 0.30000000000000004
# units_4: 256
# dense_activation_4: sigmoid
# dropout_4: 0.4
# units_5: 160
# dense_activation_5: tanh
# dropout_5: 0.1
# units_6: 32
# dense_activation_6: sigmoid
# dropout_6: 0.25
# units_7: 288
# dense_activation_7: relu
# dropout_7: 0.15000000000000002
# units_8: 160
# dense_activation_8: relu
# dropout_8: 0.1
# units_9: 512
# dense_activation_9: tanh
# dropout_9: 0.45
# units_10: 448
# dense_activation_10: relu
# dropout_10: 0.5
# tuner/epochs: 21
# tuner/initial_epoch: 0
# tuner/bracket: 0
# tuner/round: 0
# Score: 0.5988612771034241
# Trial summary
# Hyperparameters:
# units_1: 480
# dense_activation_1: sigmoid
# dropout_1: 0.4
# units_2: 416
# dense_activation_2: sigmoid
# dropout_2: 0.05
# units_3: 64
# dense_activation_3: tanh
# dropout_3: 0.4
# units_4: 96
# dense_activation_4: tanh
# dropout_4: 0.05
# units_5: 64
# dense_activation_5: tanh
# dropout_5: 0.1
# units_6: 352
# dense_activation_6: relu
# dropout_6: 0.0
# units_7: 32
# dense_activation_7: relu
# dropout_7: 0.25
# units_8: 64
# dense_activation_8: sigmoid
# dropout_8: 0.30000000000000004
# units_9: 480
# dense_activation_9: sigmoid
# dropout_9: 0.2
# units_10: 416
# dense_activation_10: sigmoid
# dropout_10: 0.30000000000000004
# tuner/epochs: 7
# tuner/initial_epoch: 0
# tuner/bracket: 1
# tuner/round: 0
# Score: 0.5921325087547302
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
