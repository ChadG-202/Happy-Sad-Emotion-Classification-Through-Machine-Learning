# %%
# Imports
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.regularizers import l2

import pickle

# Loading in X and y data
pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

# Making X data between 0 and 1
X = X.astype("float32")/255.0

# Model
model = Sequential()

model.add(Flatten(input_shape=X.shape[1:]))

model.add(Dense(64, activation='sigmoid'))
model.add(Dropout(0.05))
model.add(Dense(480, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(288, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='tanh'))
model.add(Dropout(0.35))
model.add(Dense(320, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(320, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(448, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(224, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(1, activation='sigmoid'))

# Compile
opt = keras.optimizers.Adam(learning_rate=0.0003)
model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Store and run model
history = model.fit(X, y, batch_size=32, epochs=21, validation_split=0.1)
# Out:
# Epoch 1/21
# 272/272 [==============================] - 3s 7ms/step - loss: 0.6941 - accuracy: 0.5060 - val_loss: 0.6930 - val_accuracy: 0.5062
# Epoch 2/21
# 272/272 [==============================] - 2s 6ms/step - loss: 0.6939 - accuracy: 0.4899 - val_loss: 0.6927 - val_accuracy: 0.5083
# Epoch 3/21
# 272/272 [==============================] - 2s 6ms/step - loss: 0.6931 - accuracy: 0.5014 - val_loss: 0.6908 - val_accuracy: 0.5124
# Epoch 4/21
# 272/272 [==============================] - 2s 6ms/step - loss: 0.6899 - accuracy: 0.5367 - val_loss: 0.6835 - val_accuracy: 0.5528
# Epoch 5/21
# 272/272 [==============================] - 2s 6ms/step - loss: 0.6938 - accuracy: 0.4985 - val_loss: 0.6934 - val_accuracy: 0.4917
# Epoch 6/21
# 272/272 [==============================] - 2s 7ms/step - loss: 0.6933 - accuracy: 0.4982 - val_loss: 0.6931 - val_accuracy: 0.5083
# Epoch 7/21
# ...

# %%
# Import
import matplotlib.pyplot as plt

#Plot the Loss Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Loss',fontsize=16)
plt.title('Loss Curves',fontsize=16)

#Plot the Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=18)
plt.xlabel('Epochs ',fontsize=16)
plt.ylabel('Accuracy',fontsize=16)
plt.title('Accuracy Curves',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
# Save model
#model.save('MLPClassifier.model')

# %%
# from tensorflow import keras
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
# from tensorflow.keras.regularizers import l2
# import pickle

# pickle_in = open("X.pickle","rb")
# X = pickle.load(pickle_in)

# pickle_in = open("y.pickle","rb")
# y = pickle.load(pickle_in)

# X = X.astype("float32")/255.0

# model = Sequential()

# model.add(Flatten(input_shape=X.shape[1:]))

# model.add(Dense(64, activation='sigmoid'))
# model.add(Dropout(0.05))
# model.add(Dense(480, activation='relu'))
# model.add(Dropout(0.4))

# model.add(Dense(1, activation='sigmoid'))

# opt = keras.optimizers.Adam(learning_rate=0.0005293391761557029)
# model.compile(loss='binary_crossentropy',
#               optimizer=opt,
#               metrics=['accuracy'])

# history = model.fit(X, y, batch_size=32, epochs=38, validation_split=0.1)
